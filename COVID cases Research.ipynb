# %%
#import libraries
import numpy as np 
import matplotlib.pyplot as plt
import plotly.express as px
import matplotlib.colors as mcolors
import pandas as pd 
import random
import math
import time
from sklearn.linear_model import LinearRegression, BayesianRidge
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error
import datetime
import operator 
plt.style.use('seaborn-poster')
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
import warnings
warnings.filterwarnings("ignore")

# %%
# Read or Import COVID-19 file 
new_cases = pd.read_csv(r"C:\Users\Mbetini\Desktop\new cases.csv")
cum_cases = pd.read_csv(r"C:\Users\Mbetini\Desktop\cum cases.csv")
new_vacc = pd.read_csv(r"C:\Users\Mbetini\Desktop\new vacc.csv")
cum_vacc = pd.read_csv(r"C:\Users\Mbetini\Desktop\cum vacc.csv")
deaths = pd.read_csv(r"C:\Users\Mbetini\Desktop\deaths.csv")

# %%
new_cases
# Out:
#            date  eng_new_cases  ire_new_cases  scot_new_cases  wales_new_cases
# 0    01/01/2021          28226           1223            1159             1214
# 1    02/01/2021          54180           1899            2211             2093
# 2    03/01/2021          49514           1590            2218             1810
# 3    04/01/2021          69119           1972            2376             2657
# 4    05/01/2021          58054           1591            3050             2384
# ..          ...            ...            ...             ...              ...
# 352  19/12/2021          70637           2179            5223             2891
# 353  20/12/2021         101829           2795            7658             4817
# 354  21/12/2021         101798           3881            8560             5463
# 355  22/12/2021          70549           4386             876             1646
# 356  23/12/2021          20845           1535             151                3
#
# [357 rows x 5 columns]

# %%
cum_cases

# %%
new_vacc

# %%
cum_vacc
# Out:
#            date  eng_cum_vacc  ire_cum_vacc  scott_cum_vacc  wales_cum_vacc  \
# 0    11/01/2021       2080280         84187          175942           91239
# 1    12/01/2021       2254556         91417          191965          101371
# 2    13/01/2021       2494371        102701          208207          112973
# 3    14/01/2021       2769164        114567          224840          126375
# 4    15/01/2021       3090058        117906          241924          126375
# ..          ...           ...           ...             ...             ...
# 342  19/12/2021      43250509       1392640         4372129         2482756
# 343  20/12/2021      43286601       1393753         4373917         2483556
# 344  21/12/2021      43322910       1394545         4375588         2484739
# 345  22/12/2021      43358567       1395685         4377002         2485837
# 346  23/12/2021      43388547       1396240         4378172         2486737
#
#      Unnamed: 5  Unnamed: 6  Unnamed: 7
# ...

# %%
deaths
# Out:
#            date  new_deaths  cum_deaths
# 0    01/01/2021         748       77201
# 1    02/01/2021         760       77961
# 2    03/01/2021         759       78720
# 3    04/01/2021         840       79560
# 4    05/01/2021         906       80466
# ..          ...         ...         ...
# 352  19/12/2021          94      147576
# 353  20/12/2021         103      147679
# 354  21/12/2021          72      147751
# 355  22/12/2021          80      147831
# 356  23/12/2021          26      147857
#
# [357 rows x 3 columns]

# %%
# helper method for flattening the data, so it can be displayed on a bar graph 
def flatten(arr):
    a = [] 
    arr = arr.tolist()
    for i in arr:
        a.append(i[0])
    return a

# %%
date = new_cases.keys()
eng_new_cases = []
scot_new_cases = [] 
wales_new_cases = []
ire_new_cases = []

# %%
#new covid cases
plt.figure(figsize=(16, 10))
plt.plot(new_cases.date, new_cases.eng_new_cases, color='blue' )
plt.title('New COVID-19 cases in England', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('Cases(Daily)', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.plot(new_cases.date, new_cases.scot_new_cases, color='green' )
plt.title('New COVID-19 cases in scotland', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.plot(new_cases.date, new_cases.ire_new_cases, color='purple' )
plt.title('New COVID-19 cases in Northern Ireland', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('Cases(Daily)', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.plot(new_cases.date, new_cases.wales_new_cases, color='Red' )
plt.title('New COVID-19 cases in Wales', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('Cases(Daily)', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
date = cum_cases.keys()
eng_cum_cases = []
scot_cum_cases = [] 
wales_cum_cases = []
ire_cum_cases = []

#new covid cases
plt.figure(figsize=(16, 10))
plt.plot(cum_cases.date, cum_cases.eng_cum_cases, color='blue' )
plt.title('Cumulative COVID-19 cases in England', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('cumulative Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.plot(cum_cases.date, cum_cases.scot_cum_cases, color='green' )
plt.title('Cumulative COVID-19 cases in scotland', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('Cumulative Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.plot(cum_cases.date, cum_cases.ire_cum_cases, color='purple' )
plt.title('Cumulative COVID-19 cases in Northern Ireland', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('cumulative Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.plot(cum_cases.date, cum_cases.wales_cum_cases, color='Red' )

plt.title('Cumulative COVID-19 cases in Wales', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('Cumulative Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 10))
plt.plot(cum_cases.date, cum_cases.wales_cum_cases, color='Red')
plt.plot(cum_cases.date, cum_cases.ire_cum_cases, color='purple' )
plt.plot(cum_cases.date, cum_cases.scot_cum_cases, color='green' )
plt.plot(cum_cases.date, cum_cases.eng_cum_cases, color='blue' )

plt.title('Cumulative COVID-19 cases in UK Regions', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('Cumulative Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
#UK deaths
date = deaths.keys()
new_deaths = []
cum_deaths = [] 


#new covid cases
plt.figure(figsize=(16, 10))
plt.bar(deaths.date, deaths.new_deaths, color='gold' )
plt.title('New COVID-19 Deaths United Kingdom', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('New Deaths', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.bar(deaths.date, deaths.cum_deaths, color='green' )
plt.title('Cumulative COVID-19 Deaths in the United kingdom', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('Cumulative deaths', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
#cumulative vaccinations
date = cum_vacc.keys()
eng_cum_vacc = []
scott_cum_vacc = [] 
wales_cum_vacc = []
ire_cum_vacc = []

plt.figure(figsize=(16, 10))
plt.bar(cum_vacc.date, cum_vacc.eng_cum_vacc, color='blue' )
plt.title('Cumulative COVID-19 Vaccinations(1st dose) in England', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('cumulative vaccinations', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.bar(cum_vacc.date, cum_vacc.scott_cum_vacc, color='green' )
plt.title('Cumulative COVID-19 Vaccinations(1st dose) in scotland', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('Cumulative Vaccinations', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.bar(cum_vacc.date, cum_vacc.ire_cum_vacc, color='purple' )
plt.title('Cumulative COVID-19 Vaccinations(1st dose) in Northern Ireland', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('cumulative Vaccinations', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.bar(cum_vacc.date, cum_vacc.wales_cum_vacc, color='Red' )
plt.title('Cumulative COVID-19 Vaccinations(1st dose) in Wales', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('Cumulative Vaccinations', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-5269a3c48b40> in <module>
#      25
#      26 plt.figure(figsize=(16, 10))
# ---> 27 plt.bar(cum_cases.date, cum_cases.ire_cum_vacc, color='purple' )
#      28 plt.title('Cumulative COVID-19 Vaccinations(1st dose) in Northern Ireland', size=30)
#      29 plt.xlabel('Date', size=30)
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ire_cum_vacc'

# %%
plt.figure(figsize=(16, 10))
plt.bar(cum_vacc.date, cum_vacc.ire_cum_vacc, color='purple' )
plt.title('Cumulative COVID-19 Vaccinations(1st dose) in Northern Ireland', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('cumulative Vaccinations', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 10))
plt.bar(cum_vacc.date, cum_vacc.wales_cum_vacc, color='Red' )
plt.title('Cumulative COVID-19 Vaccinations(1st dose) in Wales', size=30)
plt.xlabel('Date', size=30)
plt.ylabel('Cumulative Vaccinations', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()
